# %%
import pygame 
from pygame.locals import *
from sys import exit 

pygame.init()

musica_de_fundo = pygame.mixer.music.load('BoxCat Games - Victory.mp3')
som_colisao = pygame.mixer.Sound('smw_lost_a_life.wav')
som_powerup = pygame.mixer.Sound('smw_power-up.wav')
pygame.mixer.music.set_volume(0.05)
pygame.mixer.music.play(-1)
bigfont = pygame.font.Font(None, 80)

largura = 640
altura= 480

x = int(450)
y = int(345)

PRETO = (0,0,0)
 
tela = pygame.display.set_mode((largura,altura))
pygame.display.set_caption('Sprites')

class Raio(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('raio.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(50,50))
    
        self.rect = self.image.get_rect()
        self.rect.topleft = -200, -200
        self.lancar = False
    
    def update(self):
        if self.lancar == True:
            self.rect.y = nuvens.rect.y + 10
            self.rect.x = nuvens.rect.x
            self.lancar = False
        if self.rect.y - 50 >= altura:
            self.rect.x = -200
            self.rect.y = nuvens.rect.y + 10
            self.lancar = False
        self.rect.y += 5
        
class Cogumelo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('cogumelo1.png'))
        self.sprites.append(pygame.image.load('cogumelo2.png'))
        self.sprites.append(pygame.image.load('cogumelo3.png'))
        #self.som_cogumelo = pygame.mixer.Sound('smw_power-up_appears.wav')
        #self.som_cogumelo.set_volume(0.1)
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 2,34 * 2))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, 390
        
        self.mostrar = False
        
    
    def update(self):
        if self.mostrar == True:
            #self.som_cogumelo.play()
            self.rect.topleft = 285, 390
            self.atual = self.atual + 0.20
            if self.atual > 2:
                self.atual = 0
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(34 * 2,34 * 2))
        else:
            self.rect.topleft = -200, -200

class Alavanca(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('alavanca1.png'))
        self.sprites.append(pygame.image.load('alavanca2.png'))
        
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34,34))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, 20
        
        self.mostrar = False
        self.ativada = False
        
    
    def update(self):
        if self.mostrar == True:
            #self.som_cogumelo.play()
            if self.ativada == True:
                self.atual = 1
            self.rect.topleft = 1, 20
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(34 * 2,34 * 2))
        else:
            self.rect.topleft = -200, 20

class GaiolaRato(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('gaiola1.png'))
        self.sprites.append(pygame.image.load('gaiola2.png'))
        self.sprites.append(pygame.image.load('gaiola3.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, 102
        
        self.mostrar = False
        self.aberta = False
        
    
    def update(self):
        if self.mostrar == True:
            if self.aberta == True:
                #self.som_cogumelo.play()
                self.rect.topleft = 57, 58
                self.atual = 2
                self.image = self.sprites[int(self.atual)]
                self.image = pygame.transform.scale(self.image,(34 * 6,34 * 6))
            else:
                #self.som_cogumelo.play()
                self.rect.topleft = 100, 102
                self.atual = self.atual + 0.20
                if self.atual > 2:
                    self.atual = 0
                self.image = self.sprites[int(self.atual)]
                self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
        else:
            self.rect.topleft = -200, 102

class QueijoTiro(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('queijotiro.png'))
        #self.som_cogumelo = pygame.mixer.Sound('smw_power-up_appears.wav')
        #self.som_cogumelo.set_volume(0.1)
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30,30))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, -200
        
        self.mostrar = False
        self.alturamaximaqueijo =189
        
    
    def update(self):
        if self.mostrar == True:
            self.atual = 0
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(30,30))
            
            if self.rect.topright[0] > largura:
                 self.rect.x = queijoinimigo.rect.x
            self.rect.x += 5
        
            
            
           
            
class QueijoInimigo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('queijo1.png'))
        self.sprites.append(pygame.image.load('queijo2.png'))
   
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, 270
        
        self.mostrar = False
        
    
    def update(self):
        if self.mostrar == True:
            self.rect.topleft = 80, 270
            self.atual = self.atual + 0.20
            if self.atual > 2:
                self.atual = 0
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
        else:
            self.rect.topleft = -200, -200

class CenouraCano(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('cenouracano1.png'))
        self.sprites.append(pygame.image.load('cenouracano2.png'))
        self.sprites.append(pygame.image.load('cenouracano3.png'))
        self.sprites.append(pygame.image.load('cenouracano4.png'))
      
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 4,34 * 4))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200, -200
        
        self.mostrar = False
        self.entroucano = False
        self.apareceu_tela = False
        self.desceucano = False
        
    
    def update(self):
        if self.mostrar == True:
            self.apareceu_tela = True
            self.rect.topleft = 210, 307
            if self.entroucano == True:
                self.atual = self.atual + 0.05
                if self.atual > 3:
                    self.mostrar = False
                    personagem.mostrar = True
                    self.entroucano = False
                    self.desceucano = True
            else:
                self.atual = 0 
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(34 * 4,34 * 4))
        else:
            self.rect.topleft = -200, -200
            
class AboboraInimiga(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('abobora1.png'))
        self.sprites.append(pygame.image.load('abobora2.png'))
        self.sprites.append(pygame.image.load('abobora3.png'))
        self.sprites.append(pygame.image.load('abobora4.png'))
        self.sprites.append(pygame.image.load('aboboratontadireita1.png'))
        self.sprites.append(pygame.image.load('aboboratontadireita2.png'))
        self.sprites.append(pygame.image.load('aboboratontadireita3.png'))
        self.sprites.append(pygame.image.load('aboboratontadireita4.png'))
        self.sprites.append(pygame.image.load('aboboradano.png'))
    
        #self.som_cogumelo = pygame.mixer.Sound('smw_power-up_appears.wav')
        #self.som_cogumelo.set_volume(0.1)
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -400, 310
        
        self.posicao = 20
        self.tontadireita = False
        self.entroutontadireita = False
        self.tontaesquerda = False
        self.entroutontaesquerda = False
        self.rolardireita = True
        self.sofreudano = False
        self.apareceu_tela = False
        
        self.vida = 40
        
        self.mostrar = False
        
    
    def update(self):
        if self.mostrar == True:
            #self.som_cogumelo.play()
            self.apareceu_tela = True
            if self.tontadireita == True:
                if self.entroutontadireita == False:
                    self.atual = 4
                    self.entroutontadireita = True
                else:
                    if self.atual < 7:
                        self.atual = self.atual + 1
                    else:
                        if self.sofreudano == True:
                            self.atual = 8
                            self.tontadireita  = False
                            self.tontaesquerda = False
                            self.entroutontadireita = False
                            self.sofreudano = False
                        else:
                            self.atual = 4
            
            elif self.tontaesquerda == True:
                self.tontaesquerda = False
                self.tontadireita = False
                self.entroutontadireita = False
                self.sofreudano = False
            else:
                if self.rolardireita == True:
                    if self.rect.topright[0] <= largura:
                        if self.vida <= 20:
                            self.posicao = self.posicao + 12
                        else:
                            self.posicao = self.posicao + 7
                    else:
                        self.rolardireita = False
                        self.rolaresquerda = True
                        self.tontadireita = True
                        self.tontaesquerda = False
                elif self.rolaresquerda == True:
                    if self.rect.topright[0] >= 0:
                        if self.vida <= 20:
                            self.posicao = self.posicao - 12
                        else:
                            self.posicao = self.posicao - 7
                    else:
                        self.rolardireita = True
                        self.rolaresquerda = False
                        self.tontadireita = False
                        self.tontaesquerda = True
                self.rect.topleft = self.posicao, 310
                self.atual = self.atual + 0.20
                if self.atual > 4:
                    self.atual = 0
            self.image = self.sprites[int(self.atual)]
            self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
        else:
            self.apareceu_tela = False
            self.rect.topleft = -400, -200


class BarraVidaAbobora(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('barravida1.png'))
        self.sprites.append(pygame.image.load('barravida2.png'))
        self.sprites.append(pygame.image.load('barravida3.png'))
        self.sprites.append(pygame.image.load('barravida4.png'))
        self.sprites.append(pygame.image.load('barravida5.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30 * 7,30))
    
        self.rect = self.image.get_rect()
        self.rect.topleft = -400, 290
    
    def update(self):
        if aboborainimiga.apareceu_tela == True:
            self.image = self.sprites[self.atual]
            self.image = pygame.transform.scale(self.image,(30 * 7,30))
            self.rect.x = aboborainimiga.rect.x - 30

class BarraVidaTomate(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('barravida1.png'))
        self.sprites.append(pygame.image.load('barravida2.png'))
        self.sprites.append(pygame.image.load('barravida3.png'))
        self.sprites.append(pygame.image.load('barravida4.png'))
        self.sprites.append(pygame.image.load('barravida5.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30 * 7,30))
    
        self.rect = self.image.get_rect()
        self.rect.topleft = -200, 340
    
    def update(self):
        if tomateinimigo.apareceu_tela == True:
            self.image = self.sprites[self.atual]
            self.image = pygame.transform.scale(self.image,(30 * 7,30))
            self.rect.x = 40

class BarraVidaQueijo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('barravida1.png'))
        self.sprites.append(pygame.image.load('barravida2.png'))
        self.sprites.append(pygame.image.load('barravida3.png'))
        self.sprites.append(pygame.image.load('barravida4.png'))
        self.sprites.append(pygame.image.load('barravida5.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30 * 7,30))
    
        self.rect = self.image.get_rect()
        self.rect.topleft = -200, 240
    
    def update(self):
        if queijoinimigo.mostrar == True:
            self.image = self.sprites[self.atual]
            self.image = pygame.transform.scale(self.image,(30 * 6,30))
            self.rect.x = 45

class RatoInimigo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('rato1.png'))
        self.sprites.append(pygame.image.load('rato2.png'))
        self.sprites.append(pygame.image.load('rato3.png'))
        self.sprites.append(pygame.image.load('rato4.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30 * 3,30 * 3))
        
        self.mostrar = False
    
        self.rect = self.image.get_rect()
        self.rect.topleft = -200, 128
    
    def update(self):
        if self.mostrar == True:             
            if self.rect.y <= 210:
                self.rect.y += 2
                if self.rect.x <= 360:
                    self.rect.x += 8
                self.atual = self.atual + 0.20
                if self.atual > 2:
                    self.atual = 0
                    self.image = self.sprites[int(self.atual)]
                    self.image = pygame.transform.scale(self.image,(30 * 3,30 * 3))
            elif self.rect.y == 212:
                self.atual = 2
                self.image = self.sprites[int(self.atual)]
                self.image = pygame.transform.scale(self.image,(30 * 3,30 * 3))
            else:
                self.atual = self.atual + 0.20
                if self.atual > 5:
                    self.atual = 3
                    self.image = self.sprites[int(self.atual)]
                    self.image = pygame.transform.scale(self.image,(30 * 3,30 * 3))
                
        

class Nuvens(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('nuvens2.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
    
        self.rect = self.image.get_rect()
        self.rect.topleft = 100, 50
        self.mostrar = True
    def update(self):
        if self.mostrar == True:
            if self.rect.topright[0] > largura:
                self.rect.x = 0
            self.rect.x += 5

            if self.rect.x == 320:
                raio.lancar = True
        else:
            self.rect.topleft = -200, -200
        
class Facas(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('faca.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.center = (largura,altura -64)
        self.pontos = 0
        
    def update(self):
        if self.pontos < 10:
            if self.rect.topright[0] > largura:
                self.rect.x = 0
                self.pontos = self.pontos + 1
            self.rect.x += 10
        else:
            self.rect.x = -200
        
    def Pontos(self):
        return self.pontos

class TiroCenoura(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('cenoura_tiro.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30,30))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200,-200
        self.tiro_rodando = False
        
    def update(self):
        if tomateinimigo.apareceu_tela == True:
            if personagem.atirou == True:
                if self.tiro_rodando == True:
                    if self.rect.topright[0] < 0:
                        self.rect.x = personagem.rect.x
                        self.tiro_rodando = False
                        personagem.atirou = False
                    self.rect.x -= 10
                else:
                    if personagem.andouesquerda == True:
                        self.rect.topleft = personagem.rect.x - 20, personagem.rect.y + 40
                    elif personagem.andoudireita == True:
                        self.rect.topleft = personagem.rect.x + 95, personagem.rect.y + 40
                    self.tiro_rodando = True
            else: 
                if self.tiro_rodando == False:
                    if personagem.andouesquerda == True:
                        self.rect.topleft = personagem.rect.x - 20, personagem.rect.y + 40
                    elif personagem.andoudireita == True:
                        self.rect.topleft = personagem.rect.x + 95, personagem.rect.y + 40
                else:
                    if self.rect.topright[0] < 0:
                        self.rect.x = personagem.rect.x
                        self.tiro_rodando = False
                        personagem.atirou = False
                    self.rect.x -= 10
        elif aboborainimiga.apareceu_tela == True:
            if personagem.atirou == True:
                if self.tiro_rodando == True:
                    if personagem.atirouesquerda:
                        if self.rect.topright[0] < 0:
                            self.rect.x = personagem.rect.x
                            self.tiro_rodando = False
                            personagem.atirou = False
                        self.rect.x -= 10
                    elif personagem.atiroudireita:
                        if self.rect.topright[0] > largura:
                            self.rect.x = personagem.rect.x
                            self.tiro_rodando = False
                            personagem.atirou = False
                        self.rect.x += 10
                else:
                    if personagem.andouesquerda == True:
                        self.rect.topleft = personagem.rect.x - 20, personagem.rect.y + 40
                    elif personagem.andoudireita == True:
                        self.rect.topleft = personagem.rect.x + 95, personagem.rect.y + 40
                    self.tiro_rodando = True
            else: 
                if self.tiro_rodando == False:
                    if personagem.andouesquerda == True:
                        self.rect.topleft = personagem.rect.x - 20, personagem.rect.y + 40
                    elif personagem.andoudireita == True:
                        self.rect.topleft = personagem.rect.x + 95, personagem.rect.y + 40
                else:
                    if personagem.atirouesquerda:
                        if self.rect.topright[0] < 0:
                            self.rect.x = personagem.rect.x
                            self.tiro_rodando = False
                            personagem.atirou = False
                        self.rect.x -= 10
                    elif personagem.atiroudireita:
                        if self.rect.topright[0] > largura:
                            self.rect.x = personagem.rect.x
                            self.tiro_rodando = False
                            personagem.atirou = False
                        self.rect.x += 10
        else:
            self.rect.topleft = -200,-200
            
        
    def Pontos(self):
        return self.pontos
    
class TiroTomate(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('tomate_tiro.png'))
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(30,30))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200,400
        self.tiro_rodando = False
        
    def update(self):
        if tomateinimigo.apareceu_tela == True:
            if self.tiro_rodando == True:
                if self.rect.topright[0] > largura :
                    self.rect.x = 200 + 10
                    self.tiro_rodando = False
                    personagem.atirou = False
                self.rect.x = self.rect.x + 5
            else:
                self.rect.topleft = tomateinimigo.rect.x + 10, 400
                self.tiro_rodando = True
        
class TomateInimigo(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.sprites = []
        self.sprites.append(pygame.image.load('tomateinimigo.png'))
        self.sprites.append(pygame.image.load('tomateinimigo2.png'))
        self.sprites.append(pygame.image.load('tomateinimigodano.png'))
        self.sprites.append(pygame.image.load('tomatemorto1.png'))
        self.sprites.append(pygame.image.load('tomatemorto2.png'))
        self.sprites.append(pygame.image.load('tomatemorto3.png'))
        self.sprites.append(pygame.image.load('tomatemorto4.png'))
        self.sprites.append(pygame.image.load('tomatemorto5.png'))
        self.som_dano_inimigo = pygame.mixer.Sound('smw_sofreu_dano.wav')
        self.som_dano_inimigo.set_volume(0.2)
        
    
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = -200,-20
        self.apareceu_tela = False
        self.sofreu_dano = False
        self.vida = 40
        self.morto = False
        self.contadorbandeira = 2
        
    def update(self):
        if faca.Pontos() >= 10:
            self.apareceu_tela = True
             
            if faca.Pontos() == 10:
                mensagem_ataque = 'Pressione espaço para atacar'
                dica_ataque = fonte_dica.render(mensagem_ataque, True, (255,255,255))
                tela.blit(dica_ataque,(150,250))
            if self.vida > 0:
                if self.sofreu_dano:
                    self.sofreu_dano = False
                    self.atual = 2
                    self.vida = self.vida - 10
                    barravidatomate.atual =  barravidatomate.atual + 1
                    self.image = self.sprites[int(self.atual)]
                    self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                    self.rect = self.image.get_rect()
                    self.rect.topleft = 70,330
                    self.som_dano_inimigo.play()
                else:
                    self.atual = self.atual + 0.20
                    if self.atual >= 2:
                        self.atual = 0    
                    self.image = self.sprites[int(self.atual)]
                    self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                    self.rect = self.image.get_rect()
                    self.rect.topleft = 70,330
            else:
                self.contadorbandeira += 1
               
                if self.contadorbandeira <= 7:
                    self.atual = self.contadorbandeira     
                    self.image = self.sprites[int(self.atual)]
                    self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                else:
                    if self.contadorbandeira == 8:
                        self.atual = 3
                        self.image = self.sprites[int(self.atual)]
                        self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                    elif self.contadorbandeira == 9:
                        self.atual = 4
                        self.image = self.sprites[int(self.atual)]
                        self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                    else:
                        tomateinimigo.rect.x = -200
                        #tirotomate.rect.x = -200
                        self.apareceu_tela = False
                        if aboborainimiga.vida > 0:
                            aboborainimiga.mostrar = True
                
                
               
                barravidatomate.rect.topleft = -200,-200
                nuvens.mostrar = False
                tirotomate.rect.topleft = -200,400

                
            
    def sofrerdano(self):
        self.sofreu_dano = True
    

class Personagem(pygame.sprite.Sprite):
    def __init__(self):
        pygame.sprite.Sprite.__init__(self)
        self.som_pulo = pygame.mixer.Sound('smw_jump.wav')
        self.som_pulo.set_volume(1)
        self.sprites = []
        self.sprites.append(pygame.image.load('cenoura_0.png'))
        self.sprites.append(pygame.image.load('cenoura_1.png'))
        self.sprites.append(pygame.image.load('morte.png'))
        self.sprites.append(pygame.image.load('cenouradireita1.png'))
        self.sprites.append(pygame.image.load('cenouradireita2.png'))
        self.sprites.append(pygame.image.load('cenouraescada1.png'))
        self.sprites.append(pygame.image.load('cenouraescada2.png'))
  
        self.atual = 0
        self.image = self.sprites[self.atual]
        self.image = pygame.transform.scale(self.image,(34 * 3,34 * 3))
    
        self.rect = self.image.get_rect()
        self.mask = pygame.mask.from_surface(self.image)
        self.rect.topleft = x, y
        
        self.pulo = False
        self.morto = False
        self.anda = False
        self.atirou = False
        self.gigante = False
        self.mostrar = True
        self.cair = False
        
        self.andoudireita = False
        self.andouesquerda= True
        self.subiuescada = False
        self.desceuescada = False
        
        self.alturaqueda = 345
        self.alturamaxima = 190
        self.tamanhonormal = 3
        
        #self.animar = False
    
    #def atacar(self):
        #self.animar = True
    
    def ficargigante(self):
        self.gigante = True
        self.rect.y = 280
        
    def subirescada(self):
        self.cair = False
        self.pulo = True
        self.alturamaxima = -120
        self.alturaqueda = -20
        self.andoudireita = False 
        self.andouesquerda = False
        self.subiuescada = True
        self.desceuescada = False
        self.atual = 5
    
    def descerescada(self):
        self.cair = True
        self.pulo = False
        self.alturamaxima =  39
        self.alturaqueda = 189
        self.andoudireita = False 
        self.andouesquerda = False
        self.subiuescada = False
        self.desceuescada = True
        self.atual = 5
    
    def update(self):
        if self.mostrar == True:
            if self.morto == False:
                if self.gigante == False:
                    if self.pulo == True:
                        if self.rect.y <= self.alturamaxima:
                            #if self.anda == True:
                                #self.rect.x = x
                            self.pulo = False
                        self.rect.y -= 20
                    else:
                        #if self.anda == True:
                            #self.rect.x = x
                        if self.rect.y < self.alturaqueda :
                            self.rect.y += 20
                        else:
                            #if self.anda == True:
                                #self.rect.x = x
                            if self.atual >= 5:
                                self.atual = 3
                                self.tamanhonormal = 3
                                self.subiuescada = False
                                self.desceuescada = False
                            self.rect.y = self.alturaqueda
                else:
                    if self.cair == False:           
                        if self.pulo == True:
                            if self.rect.y <= self.alturamaxima:
                                #if self.anda == True:
                                    #self.rect.x = x
                                self.pulo = False
                            self.rect.y -= 20
                        else:
                            #if self.anda == True:
                                #self.rect.x = x
                            if self.rect.y < self.alturaqueda - 65 :
                                self.rect.y += 20
                            else:
                                #if self.anda == True:
                                    #self.rect.x = x
                                self.rect.y = self.alturaqueda - 65
                    else:
                        if self.rect.y < self.alturaqueda:
                             self.rect.y -= 20
                        
                if self.anda == True:
                    self.rect.x = x
                    if bAmbienteEsgoto == True:
                        if personagem.rect.topright[0] >= 410 and personagem.rect.topright[0] <= 452: 
                            MostraMensagemEscada()


                if self.andouesquerda == True:
                    #if self.animar == True:
                    self.atual = self.atual + 0.20
                    if self.atual > 2:
                        self.atual = 0
                        #self.animar = False
                else:
                    self.atual = self.atual + 0.20
                    if self.subiuescada == False and self.desceuescada == False :
                        if self.atual > 5:
                            self.atual = 3
                            self.tamanhonormal = 3
                    else:
                        self.tamanhonormal = 4
                        if self.atual > 7:
                            self.atual = 5
                            #self.subiuescada = False
            
                self.image = self.sprites[int(self.atual)]
                if self.gigante == True:
                    self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                else:
                    self.image = pygame.transform.scale(self.image,(34 * self.tamanhonormal,34 * self.tamanhonormal))
            else:
                self.atual = 2
                self.image = self.sprites[int(self.atual)]
                if self.gigante == True:
                    self.image = pygame.transform.scale(self.image,(34 * 5,34 * 5))
                else:
                    self.image = pygame.transform.scale(self.image,(34 * self.tamanhonormal,34 * self.tamanhonormal))
                play_again()
        else:
            self.rect.x = 1000
            
    
    def andar(self):
        self.anda = True
    
    def atirar(self):
        if tirocenoura.tiro_rodando == False:
            self.atirou = True
            if self.andoudireita == True:
                self.atiroudireita = True
                self.atirouesquerda = False
            elif self.andouesquerda:
                self.atirouesquerda = True
                self.atiroudireita = False
    
    def pular(self):
        if self.morto == False:
            self.pulo = True
            self.som_pulo.play()
        
    def morrer(self):
        self.morto = True
        som_colisao.play()
        
def MostraMensagemEscada():
    mensagem_escada = 'Pressione E para usar a escada'
    dica_escada = fonte_escada.render(mensagem_escada, True, (255,255,255))
    tela.blit(dica_escada,(275,150))

def play_again():
    text = bigfont.render('Você Morreu...', 5, (0, 0, 0))
    textx = largura / 2 - text.get_width() / 2
    texty = altura / 2 - text.get_height() / 2
    textx_size = text.get_width()
    texty_size = text.get_height()
    pygame.draw.rect(tela, (255, 255, 255), ((textx - 5, texty - 5),
                                               (textx_size + 10, texty_size +
                                                10)))

    tela.blit(text, (largura / 2 - text.get_width() / 2,
                       altura / 2 - text.get_height() / 2))

      
    
todas_as_sprites = pygame.sprite.Group()
personagem = Personagem()
nuvens = Nuvens()
faca = Facas()
tomateinimigo = TomateInimigo()
tirocenoura = TiroCenoura()
tirotomate = TiroTomate()
barravidatomate = BarraVidaTomate()
barravidaabobora = BarraVidaAbobora()
aboborainimiga = AboboraInimiga()
cenouracano = CenouraCano()
raio = Raio()
cogumelo = Cogumelo()
alavanca = Alavanca()
queijoinimigo = QueijoInimigo()
barravidaqueijo = BarraVidaQueijo()
queijotiro = QueijoTiro()
gaiolarato = GaiolaRato()
ratoinimigo = RatoInimigo()
todas_as_sprites.add(personagem)
todas_as_sprites.add(nuvens)
todas_as_sprites.add(faca)
todas_as_sprites.add(tomateinimigo)
todas_as_sprites.add(tirocenoura)
todas_as_sprites.add(tirotomate)
todas_as_sprites.add(barravidatomate)
todas_as_sprites.add(barravidaabobora)
todas_as_sprites.add(raio)
todas_as_sprites.add(cogumelo)
todas_as_sprites.add(aboborainimiga)
todas_as_sprites.add(cenouracano)
todas_as_sprites.add(queijoinimigo)
todas_as_sprites.add(barravidaqueijo)
todas_as_sprites.add(queijotiro)
todas_as_sprites.add(alavanca)
todas_as_sprites.add(gaiolarato)
todas_as_sprites.add(ratoinimigo)

grupo_obstaculos = pygame.sprite.Group()
grupo_obstaculos.add(faca)
grupo_obstaculos.add(tirotomate)
grupo_obstaculos.add(raio)
grupo_obstaculos.add(aboborainimiga)




obstaculo_cano = pygame.sprite.Group()
obstaculo_cano.add(cenouracano)

obstaculo_alavanca = pygame.sprite.Group()
obstaculo_alavanca.add(alavanca)


grupo_obstaculos_inimigo = pygame.sprite.Group()
grupo_obstaculos_inimigo.add(tirocenoura)

grupo_powerup_gigante = pygame.sprite.Group()
grupo_powerup_gigante.add(cogumelo)



relogio = pygame.time.Clock()
fonte = pygame.font.SysFont('arial', 40,True,True)
fonte_dica = pygame.font.SysFont('arial', 25,True,True)
fonte_escada = pygame.font.SysFont('arial', 15,True,True)
pontos = 0
bAmbienteEsgoto = False
while True:
    relogio.tick(30)
    tela.fill(PRETO)
    mensagem = f'Pontos: {faca.pontos}'
    texto_formatado = fonte.render(mensagem, True, (255,255,255))
    
    if aboborainimiga.mostrar == True:
        bAmbienteEsgoto = False
        imagem_fundo = pygame.image.load('cidadefundoroxo.jpeg').convert()
        imagem_fundo = pygame.transform.scale(imagem_fundo,(largura,altura))
    else:
        if cenouracano.apareceu_tela == True:
            if cenouracano.desceucano == True:
                personagem.mostrar = True
                alavanca.mostrar = True
                gaiolarato.mostrar = True
                queijoinimigo.mostrar = True
                if queijotiro.mostrar == False:
                    x = 498
                    queijotiro.rect.topleft = queijoinimigo.rect.x,250
                
                queijotiro.mostrar = True
                bAmbienteEsgoto = True
                imagem_fundo = pygame.image.load('esgoto.jpg').convert()
                imagem_fundo = pygame.transform.scale(imagem_fundo,(largura,altura))
            else:
                bAmbienteEsgoto = False
                imagem_fundo = pygame.image.load('cidadefundoroxo.jpeg').convert()
                imagem_fundo = pygame.transform.scale(imagem_fundo,(largura,altura))
        else:
            bAmbienteEsgoto = False
            imagem_fundo = pygame.image.load('cidadefundo.jpg').convert()
            imagem_fundo = pygame.transform.scale(imagem_fundo,(largura,altura))
    
    for event in pygame.event.get():
        if event.type == QUIT:
            pygame.quit()
            exit()
        if event.type == KEYDOWN:
            if event.key == K_SPACE:
                if tomateinimigo.apareceu_tela or aboborainimiga.apareceu_tela:
                    personagem.atirar()
            if event.key == K_w:
                if bAmbienteEsgoto == True:
                    if personagem.rect.topright[0] > 600:
                        personagem.alturamaxima = 100

                    if personagem.rect.topright[0] >= 400 and personagem.rect.topright[0] < 540:
                        personagem.alturamaxima = 39

                    if personagem.rect.topright[0] < 400 and personagem.rect.topright[0] > 300:
                        personagem.alturamaxima = 100   

                    if personagem.rect.topright[0] <= 300:
                        personagem.alturamaxima = 80 
                    personagem.pular()
                else:
                    personagem.pular()
            if event.key == K_e:
                if bAmbienteEsgoto == True:
                    if personagem.rect.topright[0] >= 410 and personagem.rect.topright[0] <= 452:
                        if personagem.rect.y > 0:
                            personagem.subirescada()
                        else:
                            personagem.descerescada()
    if pygame.key.get_pressed()[K_a]:
        if bAmbienteEsgoto == True:
            personagem.subiuescada = False
            personagem.desceuescada = False
            personagem.tamanhonormal = 3
            if personagem.rect.y > 0:
                if personagem.rect.topright[0] - 20 < 540: 
                    if personagem.rect.y >= 190:
                        if personagem.rect.topright[0] < 400:
                            x = x - 20
                            personagem.andouesquerda = True
                            personagem.andoudireita = False
                            personagem.atual = 0
                            personagem.andar()
                            if personagem.rect.topright[0] < 300:
                                personagem.cair = True 
                                personagem.alturaqueda = 250
                        else:
                            personagem.atual = 0
                            personagem.andouesquerda = True
                            personagem.andoudireita = False
                    else:
                        x = x - 20
                        personagem.andouesquerda = True
                        personagem.andoudireita = False
                        personagem.atual = 0
                        personagem.andar() 
                        personagem.cair = True 
                        if personagem.rect.topright[0] < 400:
                            personagem.alturaqueda = 230
                        else:
                            personagem.alturaqueda = 189
                else:
                    if personagem.rect.topright[0] - 20 < 600: 
                        x = x - 20
                        personagem.andouesquerda = True
                        personagem.andoudireita = False
                        personagem.atual = 0
                        personagem.andar() 
                        if personagem.rect.y >= 190:
                            personagem.cair = True 
                            personagem.alturaqueda = 340
                    else:
                        x = x - 20
                        personagem.andouesquerda = True
                        personagem.andoudireita = False
                        personagem.atual = 0
                        personagem.andar() 
            else:
                x = x - 20
                personagem.cair = True 
                personagem.alturaqueda = -10
                personagem.andouesquerda = True
                personagem.andoudireita = False
                personagem.atual = 0
                personagem.andar() 
        else:
            x = x - 20
            personagem.andouesquerda = True
            personagem.andoudireita = False
            personagem.atual = 0
            personagem.andar()
    if pygame.key.get_pressed()[K_d]:
        if bAmbienteEsgoto == True:
            personagem.subiuescada = False
            personagem.desceuescada = False
            personagem.tamanhonormal = 3
            if personagem.rect.y > 0:
                if personagem.rect.topright[0] + 20 > 600: 
                    if personagem.rect.y > 250:
                        print('parado')
                    else:
                        x = x + 20
                        personagem.andoudireita = True
                        personagem.andouesquerda = False
                        personagem.atual = 3
                        personagem.andar()
                        personagem.alturaqueda = 250
                        personagem.cair = True
                else:
                    if personagem.rect.topright[0] > 360:
                        x = x + 20
                        personagem.andoudireita = True
                        personagem.andouesquerda = False
                        personagem.atual = 3
                        personagem.alturamaxima = 190
                        personagem.andar()
                        if personagem.rect.topright[0] > 495:
                            personagem.alturaqueda = 340
                            personagem.cair = True
                    elif personagem.rect.topright[0] < 360 and personagem.rect.y <= 250:
                        if personagem.rect.topright[0] + 20 < 360 or personagem.rect.y <= 189 :
                            x = x + 20
                            personagem.andoudireita = True
                            personagem.andouesquerda = False
                            personagem.atual = 3
                            personagem.andar()

                            if personagem.rect.topright[0] > 255:
                                personagem.cair = True 
                                personagem.alturaqueda = 230  
                    else:
                        if personagem.rect.y < 189:
                            x = x + 20
                            personagem.andoudireita = True
                            personagem.andouesquerda = False
                            personagem.atual = 3
                            personagem.andar()
                            personagem.alturaqueda = 189
                            personagem.cair = True
                        else:
                            personagem.atual = 3
                            personagem.andoudireita = True
                            personagem.andouesquerda = False
            else:
                x = x + 20
                personagem.cair = True 
                personagem.alturaqueda = -10
                personagem.andoudireita = True
                personagem.andouesquerda = False
                personagem.atual = 3
                personagem.andar()
        else:
            x = x + 20
            personagem.andoudireita = True
            personagem.andouesquerda = False
            personagem.atual = 3
            personagem.andar()
    
    colisoes = pygame.sprite.spritecollide(personagem, grupo_obstaculos, True, pygame.sprite.collide_mask)
    
    colisoes_tomateinimigo = pygame.sprite.spritecollide(tomateinimigo, grupo_obstaculos_inimigo, False, pygame.sprite.collide_mask)
      
    colisoes_aboborainimiga = pygame.sprite.spritecollide(aboborainimiga, grupo_obstaculos_inimigo, False, pygame.sprite.collide_mask)
    
    pegoucogumelo = pygame.sprite.spritecollide(personagem, grupo_powerup_gigante, True, pygame.sprite.collide_mask)
    
    entroucano = pygame.sprite.spritecollide(personagem, obstaculo_cano, False, pygame.sprite.collide_mask)
    
    ativoualavanca = pygame.sprite.spritecollide(personagem, obstaculo_alavanca, False, pygame.sprite.collide_mask)
    
    if ativoualavanca:
        if alavanca.ativada == False:
            alavanca.ativada = True
            gaiolarato.aberta = True
            ratoinimigo.mostrar = True
            ratoinimigo.rect.x = 85
    
    if entroucano:
        cenouracano.entroucano = True
        personagem.mostrar = False
    
    if pegoucogumelo:
        #cogumelo.som_cogumelo.set_volume(0)
        personagem.ficargigante()
        som_powerup.set_volume(1)
        som_powerup.play()
        
    tela.blit(imagem_fundo,(0,0))
    todas_as_sprites.draw(tela)
    
    if colisoes_tomateinimigo:
        faca.pontos = faca.pontos + 1
        tirocenoura.tiro_rodando = False
        personagem.atirou = False
        tomateinimigo.sofrerdano()
    
    if colisoes_aboborainimiga:
        faca.pontos = faca.pontos + 1
        aboborainimiga.sofreudano = True
        if personagem.atirou == True:
            aboborainimiga.vida -= 10
        print(aboborainimiga.vida)
        if aboborainimiga.vida == 0:
            aboborainimiga.mostrar = False
            aboborainimiga.apareceu_tela = False
            barravidaabobora.rect.x = -200
            cenouracano.mostrar = True
        if barravidaabobora.atual < 4:
            if personagem.atirou == True:
                barravidaabobora.atual = barravidaabobora.atual + 1
        else:
            barravidaabobora.atual = 0 
        tirocenoura.tiro_rodando = False
        personagem.atirou = False
    if colisoes:
        personagem.morrer()
        pass
    else:
        todas_as_sprites.update()
            
    tela.blit(texto_formatado,(420,40))
    pygame.display.flip()
